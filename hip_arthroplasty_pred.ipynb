# %% [markdown]
# <a href="https://colab.research.google.com/github/Gzim30/Gzim30/blob/main/hip_arthroplasty_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#      <input type="file" id="files-d0a9d63a-c7cf-47d1-98ba-fef3e7385b31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0a9d63a-c7cf-47d1-98ba-fef3e7385b31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-91efb287-4c68-4384-9dbb-00df87b0f69d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91efb287-4c68-4384-9dbb-00df87b0f69d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator



# Define the CNN model
model = Sequential()

# Convolutional layers
model.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten layer
model.add(Flatten())

# Fully connected layers
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Image data augmentation to prevent overfitting
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
training_set = train_datagen.flow_from_directory(dataset_path, target_size=(64, 64), batch_size=32, class_mode='binary')

# Train the model
model.fit(training_set, epochs=25)

# Save the model
model.save('image_recognition_model.h5')
# Out:
# Found 206 images belonging to 2 classes.
# Epoch 1/25
# 7/7 [==============================] - 3s 249ms/step - loss: 0.7343 - accuracy: 0.4563
# Epoch 2/25
# 7/7 [==============================] - 2s 248ms/step - loss: 0.6980 - accuracy: 0.5388
# Epoch 3/25
# 7/7 [==============================] - 3s 438ms/step - loss: 0.6915 - accuracy: 0.5583
# Epoch 4/25
# 7/7 [==============================] - 3s 422ms/step - loss: 0.6917 - accuracy: 0.6117
# Epoch 5/25
# 7/7 [==============================] - 2s 281ms/step - loss: 0.6897 - accuracy: 0.5534
# Epoch 6/25
# 7/7 [==============================] - 2s 244ms/step - loss: 0.6863 - accuracy: 0.5437
# Epoch 7/25
# 7/7 [==============================] - 2s 251ms/step - loss: 0.6865 - accuracy: 0.5388
# Epoch 8/25
# 7/7 [==============================] - 3s 435ms/step - loss: 0.6813 - accuracy: 0.5437
# Epoch 9/25
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6819 - accuracy: 0.5631
# Epoch 10/25
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have the 'history' object after training
history = model.fit(training_set, epochs=25)

# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/25
# 7/7 [==============================] - 5s 620ms/step - loss: 0.5002 - accuracy: 0.7767
# Epoch 2/25
# 7/7 [==============================] - 5s 683ms/step - loss: 0.4614 - accuracy: 0.7621
# Epoch 3/25
# 7/7 [==============================] - 2s 272ms/step - loss: 0.5026 - accuracy: 0.7573
# Epoch 4/25
# 7/7 [==============================] - 2s 247ms/step - loss: 0.4815 - accuracy: 0.7913
# Epoch 5/25
# 7/7 [==============================] - 2s 246ms/step - loss: 0.5075 - accuracy: 0.7573
# Epoch 6/25
# 7/7 [==============================] - 2s 244ms/step - loss: 0.4400 - accuracy: 0.8010
# Epoch 7/25
# 7/7 [==============================] - 2s 280ms/step - loss: 0.4138 - accuracy: 0.8204
# Epoch 8/25
# 7/7 [==============================] - 3s 430ms/step - loss: 0.4187 - accuracy: 0.8107
# Epoch 9/25
# 7/7 [==============================] - 2s 294ms/step - loss: 0.4702 - accuracy: 0.7961
# Epoch 10/25
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have the 'history' object after training
history = model.fit(training_set, epochs=25)

# Plot training accuracy and loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/25
# 7/7 [==============================] - 3s 279ms/step - loss: 0.3720 - accuracy: 0.8398
# Epoch 2/25
# 7/7 [==============================] - 2s 248ms/step - loss: 0.3599 - accuracy: 0.8641
# Epoch 3/25
# 7/7 [==============================] - 2s 240ms/step - loss: 0.3006 - accuracy: 0.8786
# Epoch 4/25
# 7/7 [==============================] - 2s 331ms/step - loss: 0.2710 - accuracy: 0.8981
# Epoch 5/25
# 7/7 [==============================] - 3s 430ms/step - loss: 0.2717 - accuracy: 0.8932
# Epoch 6/25
# 7/7 [==============================] - 2s 241ms/step - loss: 0.3053 - accuracy: 0.8786
# Epoch 7/25
# 7/7 [==============================] - 2s 246ms/step - loss: 0.2491 - accuracy: 0.8835
# Epoch 8/25
# 7/7 [==============================] - 2s 241ms/step - loss: 0.2279 - accuracy: 0.9320
# Epoch 9/25
# 7/7 [==============================] - 2s 239ms/step - loss: 0.2074 - accuracy: 0.9320
# Epoch 10/25
# ...
